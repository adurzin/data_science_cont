# %%
import pandas as pd
import numpy as np
import pickle
import random

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, ShuffleSplit, cross_val_score, learning_curve
from sklearn.model_selection import KFold, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, f1_score, precision_score, recall_score

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb, lightgbm as lgbm, catboost as catb

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

import warnings
warnings.simplefilter('ignore')

# %%
def get_classification_report(y_train_true, y_train_pred, y_test_true, y_test_pred):
    print('TRAIN\n\n' + classification_report(y_train_true, y_train_pred))
    print('TEST\n\n' + classification_report(y_test_true, y_test_pred))
    print('CONFUSION MATRIX\n')
    print(pd.crosstab(y_test_true, y_test_pred))

# %%
def balance_df_by_target(df, target_name):

    target_counts = df[target_name].value_counts()

    major_class_name = target_counts.argmax()
    minor_class_name = target_counts.argmin()

    disbalance_coeff = int(target_counts[major_class_name] / target_counts[minor_class_name]) - 1

    for i in range(disbalance_coeff):
        sample = df[df[target_name] == minor_class_name].sample(target_counts[minor_class_name])
        df = df.append(sample, ignore_index=True)

    return df.sample(frac=1)

# %% [markdown]
# ### Описание датасета

# %% [markdown]
# * **Home Ownership** - домовладение
# * **Annual Income** - годовой доход
# * **Years in current job** - количество лет на текущем месте работы
# * **Tax Liens** - налоговые обременения
# * **Number of Open Accounts** - количество открытых счетов
# * **Years of Credit History** - количество лет кредитной истории
# * **Maximum Open Credit** - наибольший открытый кредит
# * **Number of Credit Problems** - количество проблем с кредитом
# * **Months since last delinquent** - количество месяцев с последней просрочки платежа
# * **Bankruptcies** - банкротства
# * **Purpose** - цель кредита
# * **Term** - срок кредита
# * **Current Loan Amount** - текущая сумма кредита
# * **Current Credit Balance** - текущий кредитный баланс
# * **Monthly Debt** - ежемесячный долг
# * **Credit Default** - факт невыполнения кредитных обязательств (0 - погашен вовремя, 1 - просрочка)

# %% [markdown]
# **Пути к директориям и файлам**

# %%
TRAIN_DATASET_PATH = './course_project_train.csv'
TEST_DATASET_PATH = './course_project_test.csv'

# %% [markdown]
# **Загрузка данных**

# %%
df = pd.read_csv(TRAIN_DATASET_PATH)

df_test = pd.read_csv(TEST_DATASET_PATH)

df.shape, df_test.shape
# Out:
# ((7500, 17), (2500, 16))

# %% [markdown]
# # Уменьшение объема памяти датасета

# %%
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col]. astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
                       
            else:
                if c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                       df[col] = df[col].astype(np.float32)
                else:
                       df[col] = df[col].astype(np.float64)

    
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:1f}%'.format(100 * (start_mem - end_mem) / start_mem))
                       
    return df

# %%
reduce_mem_usage(df)
# Out:
# Memory usage of dataframe is 0.97 MB
# Memory usage after optimization is: 0.58 MB
# Decreased by 40.436102%
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0          Own Home       482087.0                  NaN        0.0
# 1          Own Home      1025487.0            10+ years        0.0
# 2     Home Mortgage       751412.0              8 years        0.0
# 3          Own Home       805068.0              6 years        0.0
# 4              Rent       776264.0              8 years        0.0
# ...             ...            ...                  ...        ...
# 7495           Rent       402192.0             < 1 year        0.0
# 7496  Home Mortgage      1533984.0               1 year        0.0
# 7497           Rent      1878910.0              6 years        0.0
# 7498  Home Mortgage            NaN                  NaN        0.0
# 7499           Rent            NaN              4 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                26.299999             685960.0
# 1                        15.0                15.300000            1181730.0
# 2                        11.0                35.000000            1182434.0
# 3                         8.0                22.500000             147400.0
# 4                        13.0                13.600000             385836.0
# ...                       ...                      ...                  ...
# 7495                      3.0                 8.500000             107866.0
# 7496                     10.0                26.500000             686312.0
# 7497                     12.0                32.099998            1778920.0
# 7498                     21.0                26.500000            1141250.0
# 7499                      8.0                 9.400000             480832.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           1.0                           NaN           1.0
# 1                           0.0                           NaN           0.0
# 2                           0.0                           NaN           0.0
# 3                           1.0                           NaN           1.0
# 4                           1.0                           NaN           0.0
# ...                         ...                           ...           ...
# 7495                        0.0                           NaN           0.0
# 7496                        0.0                          43.0           0.0
# 7497                        0.0                           NaN           0.0
# 7498                        0.0                           NaN           0.0
# 7499                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 0     debt consolidation  Short Term          100000000.0
# 1     debt consolidation   Long Term             264968.0
# 2     debt consolidation  Short Term          100000000.0
# 3     debt consolidation  Short Term             121396.0
# 4     debt consolidation  Short Term             125840.0
# ...                  ...         ...                  ...
# 7495               other  Short Term             129360.0
# 7496  debt consolidation   Long Term             444048.0
# 7497           buy a car  Short Term          100000000.0
# 7498  debt consolidation  Short Term             615274.0
# 7499  debt consolidation  Short Term              26928.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                    47386.0        7914.0         749.0               0
# 1                   394972.0       18373.0         737.0               1
# 2                   308389.0       13651.0         742.0               0
# 3                    95855.0       11338.0         694.0               0
# 4                    93309.0        7180.0         719.0               0
# ...                      ...           ...           ...             ...
# 7495                 73492.0        1900.0         697.0               0
# 7496                456399.0       12783.0        7410.0               1
# 7497                477812.0       12479.0         748.0               0
# 7498                476064.0       37118.0           NaN               0
# 7499                288192.0        9061.0           NaN               0
#
# [7500 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Home Ownership                7500 non-null   object
#  1   Annual Income                 5943 non-null   float32
#  2   Years in current job          7129 non-null   object
#  3   Tax Liens                     7500 non-null   float32
#  4   Number of Open Accounts       7500 non-null   float32
#  5   Years of Credit History       7500 non-null   float32
#  6   Maximum Open Credit           7500 non-null   float32
#  7   Number of Credit Problems     7500 non-null   float32
#  8   Months since last delinquent  3419 non-null   float32
#  9   Bankruptcies                  7486 non-null   float32
#  10  Purpose                       7500 non-null   object
#  11  Term                          7500 non-null   object
#  12  Current Loan Amount           7500 non-null   float32
#  13  Current Credit Balance        7500 non-null   float32
#  14  Monthly Debt                  7500 non-null   float32
#  15  Credit Score                  5943 non-null   float32
#  16  Credit Default                7500 non-null   int8
# dtypes: float32(12), int8(1), object(4)
# memory usage: 593.4+ KB

# %%
plt.figure(figsize=(16, 8))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='seismic')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

# %% [markdown]
# # Обработка выбросов

# %% [markdown]
# ### Annual Income

# %%
df['Annual Income'].describe()
# Out:
# count    5.943000e+03
# mean     1.366392e+06
# std      8.453392e+05
# min      1.645970e+05
# 25%      8.443410e+05
# 50%      1.168386e+06
# 75%      1.640137e+06
# max      1.014934e+07
# Name: Annual Income, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x='Annual Income', data=df)
plt.show()

# %%
Annual_Income_max = df['Annual Income'].quantile(0.975)
Annual_Income_max
# Out:
# 3444213.5

# %%
df.loc[df['Annual Income'] > Annual_Income_max, 'Annual Income'] = None

# %% [markdown]
# ### Current Credit Balance

# %%
df['Current Credit Balance'].describe()
# Out:
# count    7.500000e+03
# mean     2.898332e+05
# std      3.178714e+05
# min      0.000000e+00
# 25%      1.142565e+05
# 50%      2.093230e+05
# 75%      3.604062e+05
# max      6.506797e+06
# Name: Current Credit Balance, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x='Current Credit Balance', data=df)
plt.show()

# %%
Current_Credit_Balance_max = df['Current Credit Balance'].quantile(0.975)
Current_Credit_Balance_max
# Out:
# 1001579.7749999975

# %%
df.loc[(df['Current Credit Balance'] > Current_Credit_Balance_max), 'Current Credit Balance'] = df['Current Credit Balance'].median()

# %% [markdown]
# ### Number of Open Accounts

# %%
df['Number of Open Accounts'].describe()
# Out:
# count    7500.000000
# mean       11.130934
# std         4.908924
# min         2.000000
# 25%         8.000000
# 50%        10.000000
# 75%        14.000000
# max        43.000000
# Name: Number of Open Accounts, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x='Number of Open Accounts', data=df)
plt.show()

# %%
df.loc[df['Number of Open Accounts'] > 25, 'Number of Open Accounts'].value_counts()
# Out:
# 28.0    14
# 27.0    14
# 26.0    12
# 30.0    11
# 29.0    10
# 32.0     6
# 33.0     6
# 31.0     6
# 34.0     2
# 37.0     2
# 43.0     1
# 41.0     1
# 38.0     1
# 35.0     1
# 42.0     1
# Name: Number of Open Accounts, dtype: int64

# %%
df.loc[df['Number of Open Accounts'] > 25, 'Number of Open Accounts'] = None

# %% [markdown]
# ### Current Loan Amount

# %%
df['Current Loan Amount'].describe()
# Out:
# count         7500.0
# mean      11873178.0
# std       31926124.0
# min          11242.0
# 25%         180169.0
# 50%         309573.0
# 75%         519882.0
# max      100000000.0
# Name: Current Loan Amount, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(df['Current Loan Amount'])
plt.show()

# %%
df.loc[df['Current Loan Amount'] > 700000]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0          Own Home       482087.0                  NaN        0.0
# 2     Home Mortgage       751412.0              8 years        0.0
# 6     Home Mortgage      1511108.0            10+ years        0.0
# 22             Rent       463790.0                  NaN        0.0
# 27             Rent      1004055.0              8 years        0.0
# ...             ...            ...                  ...        ...
# 7464  Home Mortgage      1159152.0              6 years        0.0
# 7475           Rent       848426.0            10+ years        0.0
# 7478  Home Mortgage            NaN              6 years        0.0
# 7489  Home Mortgage      1394942.0            10+ years        0.0
# 7497           Rent      1878910.0              6 years        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                        11.0                26.299999             685960.0
# 2                        11.0                35.000000            1182434.0
# 6                         9.0                20.299999             388124.0
# 22                        6.0                28.299999             288442.0
# 27                        7.0                14.500000             328394.0
# ...                       ...                      ...                  ...
# 7464                     14.0                22.000000             389356.0
# 7475                      8.0                20.100000             526306.0
# 7478                      NaN                16.299999            1435456.0
# 7489                     15.0                27.200001            1441396.0
# 7497                     12.0                32.099998            1778920.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 0                           1.0                           NaN           1.0
# 2                           0.0                           NaN           0.0
# 6                           0.0                          73.0           0.0
# 22                          0.0                           NaN           0.0
# 27                          0.0                           NaN           0.0
# ...                         ...                           ...           ...
# 7464                        1.0                          77.0           1.0
# 7475                        0.0                          12.0           0.0
# 7478                        0.0                          21.0           0.0
# 7489                        0.0                          35.0           0.0
# 7497                        0.0                           NaN           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 0     debt consolidation  Short Term          100000000.0
# 2     debt consolidation  Short Term          100000000.0
# 6      home improvements  Short Term          100000000.0
# 22    debt consolidation  Short Term          100000000.0
# 27    debt consolidation  Short Term          100000000.0
# ...                  ...         ...                  ...
# 7464  debt consolidation  Short Term          100000000.0
# 7475  debt consolidation  Short Term          100000000.0
# 7478  debt consolidation  Short Term             787864.0
# 7489  debt consolidation  Short Term             753764.0
# 7497           buy a car  Short Term          100000000.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 0                    47386.0        7914.0         749.0               0
# 2                   308389.0       13651.0         742.0               0
# 6                    51623.0        2317.0         745.0               0
# 22                  157700.0        5063.0         738.0               0
# 27                  195966.0        6041.0         734.0               0
# ...                      ...           ...           ...             ...
# 7464                 49438.0       18257.0         737.0               0
# 7475                 83638.0       16473.0         742.0               0
# 7478                402914.0       93640.0         703.0               0
# 7489                496698.0       16972.0         742.0               1
# 7497                477812.0       12479.0         748.0               0
#
# [1162 rows x 17 columns]

# %%
df.loc[df['Current Loan Amount'] > 700000, 'Current Loan Amount'] = None

# %% [markdown]
# ### Monthly Debt

# %%
df['Monthly Debt'].describe()
# Out:
# count      7500.000000
# mean      18314.453125
# std       11926.764648
# min           0.000000
# 25%       10067.500000
# 50%       16076.500000
# 75%       23818.000000
# max      136679.000000
# Name: Monthly Debt, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(df['Monthly Debt'])
plt.show()

# %%
df['Monthly Debt'].quantile(.975)
# Out:
# 47950.149999999965

# %%
df.loc[df['Monthly Debt'] > 47950, 'Monthly Debt'] = None

# %%
df.loc[df['Monthly Debt'] < 4000, ['Credit Default']].value_counts()
# Out:
# Credit Default
# 0                 337
# 1                  98
# dtype: int64

# %% [markdown]
# ### Tax Liens

# %%
df['Tax Liens'].describe()
# Out:
# count    7500.000000
# mean        0.030133
# std         0.271604
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         7.000000
# Name: Tax Liens, dtype: float64

# %%
sns.catplot(x='Tax Liens',
            y='Credit Default',
            kind='bar',
            data=df);

# %% [markdown]
# ### Years of Credit History

# %%
df['Years of Credit History'].describe()
# Out:
# count    7500.000000
# mean       18.317467
# std         7.041946
# min         4.000000
# 25%        13.500000
# 50%        17.000000
# 75%        21.799999
# max        57.700001
# Name: Years of Credit History, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(df['Years of Credit History'])
plt.show()

# %%
df.loc[df['Years of Credit History'] > 35, 'Years of Credit History'] = None

# %% [markdown]
# ### Maximum Open Credit

# %%
df['Maximum Open Credit'].describe()
# Out:
# count    7.500000e+03
# mean     9.451538e+05
# std      1.602622e+07
# min      0.000000e+00
# 25%      2.792295e+05
# 50%      4.781590e+05
# 75%      7.935015e+05
# max      1.304726e+09
# Name: Maximum Open Credit, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(df['Maximum Open Credit'])
plt.show()

# %%
df.loc[(df['Maximum Open Credit'] > 3400000), 'Maximum Open Credit'] = None

# %% [markdown]
# ### Months since last delinquent

# %%
df['Months since last delinquent'].describe()
# Out:
# count    3419.000000
# mean       34.692600
# std        21.688807
# min         0.000000
# 25%        16.000000
# 50%        32.000000
# 75%        50.000000
# max       118.000000
# Name: Months since last delinquent, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(df['Months since last delinquent'])
plt.show()

# %%
df.loc[df['Months since last delinquent'] > 95, 'Months since last delinquent'] = None

# %% [markdown]
# ### Bankruptcies

# %%
df['Bankruptcies'].describe()
# Out:
# count    7486.000000
# mean        0.117152
# std         0.347192
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         4.000000
# Name: Bankruptcies, dtype: float64

# %%
sns.catplot(x='Bankruptcies',
            y='Credit Default',
            kind='violin',
            data=df);

# %%
df['Bankruptcies'].value_counts()
# Out:
# 0.0    6660
# 1.0     786
# 2.0      31
# 3.0       7
# 4.0       2
# Name: Bankruptcies, dtype: int64

# %% [markdown]
# ### Credit Score

# %%
df['Credit Score'].describe()
# Out:
# count    5943.000000
# mean     1151.087524
# std      1604.451416
# min       585.000000
# 25%       711.000000
# 50%       731.000000
# 75%       743.000000
# max      7510.000000
# Name: Credit Score, dtype: float64

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(df['Credit Score'])
plt.show()

# %%
df.loc[(df['Credit Score'] > 700), 'Credit Default'].value_counts()
# Out:
# 0    3691
# 1    1218
# Name: Credit Default, dtype: int64

# %%
df.loc[(df['Credit Score'] > 751) | (df['Credit Score'] < 680)]
# Out:
#      Home Ownership  Annual Income Years in current job  Tax Liens  \
# 17    Home Mortgage      3361898.0              3 years        0.0
# 40             Rent       709821.0            10+ years        0.0
# 69    Home Mortgage      1408527.0              2 years        0.0
# 74    Home Mortgage      1435127.0             < 1 year        0.0
# 87    Home Mortgage      1533566.0              7 years        0.0
# ...             ...            ...                  ...        ...
# 7460           Rent       769462.0              5 years        0.0
# 7461  Home Mortgage       914090.0             < 1 year        2.0
# 7483           Rent       567435.0              8 years        0.0
# 7493           Rent      1257610.0              8 years        0.0
# 7496  Home Mortgage      1533984.0               1 year        0.0
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 17                       14.0                28.500000            1042096.0
# 40                       13.0                23.700001             339724.0
# 69                       12.0                17.500000             700062.0
# 74                       10.0                21.200001            1643906.0
# 87                       11.0                14.800000             715462.0
# ...                       ...                      ...                  ...
# 7460                      8.0                17.000000             313786.0
# 7461                     14.0                16.799999             101398.0
# 7483                     11.0                17.100000             365750.0
# 7493                     14.0                16.500000             821480.0
# 7496                     10.0                26.500000             686312.0
#
#       Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# 17                          0.0                           NaN           0.0
# 40                          0.0                          65.0           0.0
# 69                          0.0                          21.0           0.0
# 74                          0.0                          68.0           0.0
# 87                          0.0                          19.0           0.0
# ...                         ...                           ...           ...
# 7460                        0.0                          80.0           0.0
# 7461                        2.0                          34.0           0.0
# 7483                        0.0                           8.0           0.0
# 7493                        0.0                          58.0           0.0
# 7496                        0.0                          43.0           0.0
#
#                  Purpose        Term  Current Loan Amount  \
# 17    debt consolidation   Long Term             498872.0
# 40    debt consolidation   Long Term             246004.0
# 69                 other   Long Term             525998.0
# 74    debt consolidation   Long Term             443124.0
# 87    debt consolidation  Short Term             210826.0
# ...                  ...         ...                  ...
# 7460  debt consolidation  Short Term             109186.0
# 7461   home improvements   Long Term             350064.0
# 7483  debt consolidation   Long Term             328526.0
# 7493  debt consolidation   Long Term             448052.0
# 7496  debt consolidation   Long Term             444048.0
#
#       Current Credit Balance  Monthly Debt  Credit Score  Credit Default
# 17                  689396.0           NaN         644.0               1
# 40                  198341.0       14670.0         670.0               1
# 69                  174135.0        9320.0        6470.0               1
# 74                  782268.0       28487.0         674.0               0
# 87                  285475.0       18147.0        7440.0               1
# ...                      ...           ...           ...             ...
# 7460                 45524.0        4585.0        7470.0               1
# 7461                 58748.0       16225.0         669.0               1
# 7483                181944.0        6431.0         658.0               1
# 7493                167428.0       27562.0         676.0               1
# 7496                456399.0       12783.0        7410.0               1
#
# [910 rows x 17 columns]

# %%
df.loc[(df['Credit Score'] > 751) | (df['Credit Score'] < 680), 'Credit Score'] = None

# %%
sns.catplot(y='Credit Score',
            x='Credit Default',
            kind='box',
            data=df);

# %%
plt.figure(figsize=(16, 8))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True, cmap='seismic')
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':18}, pad=12);

# %% [markdown]
# # Заполнение пропусков

# %% [markdown]
# ### Bankruptcies
